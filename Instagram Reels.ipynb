# %%
from textblob import TextBlob
import pandas as pd

# Reel 1: अनंत अंबानी ने अंबाजी मंदिर के बारे में क्या कहा? (Mythology Story)

comments = [
    "Maa❤️❤️❤️❤️❤️❤️",
    "I love you and your naychiral work",
    "❤️❤️❤️❤️",
    "Maa ♥️♥️",
    "🙏🙏♥️♥️",
    "Jai ho,❤️❤️❤️❤️❤️🙏🙏🙏🙏",
    "जय माता जी",
    "Jai ho 🙏🌺",
    "Jay Shree Ambe 🙏🏻🙇🏻‍♂️💓",
    "❤️‍🩹❤️‍🩹❤️‍🩹❤️‍🩹❤️‍🩹❤️‍🩹❤️‍🩹❤️‍🩹",
    "👏👏👏👏",
    "Allah Hu Akbar 😎🌟🙌🙌❤️❤️",
    "Jay ambe👏👏🙏🚩",
    "जय श्री राम",
    "Jai jai ambe ❤️",
    "Jay ambe maa 🙏🏻",
    "🙏🏻🙏🏻",
    "Jai Mata di",
    "Jai Mata di",
    "Jay shree siyaram 🙏❤️❤️",
    "Jay ambe maa 🙏",
    "🙏",
    "Jay shree ambe 🙏",
    "જય માતાજી ❤️🙏",
    "Jai mata di",
    "Jai mata di",
    "Jai mata di",
    "Jai mata di",
    "માઁ 🙏",
    "Jay shree ram",
    "Jay Ambe ma🙏🚩",
    "🙏🙏🙏🙏जय अंबाजी माता 🙏🙏🙏",
    "🙏🙏",
    "jay mataji🙏🙏",
    "Jai maa ambey",
    "Jay Mata Di 🙏",
    "👏👏👏👏👏👏👏🍦",
    "🙏🙏🙏🙏🙏🙏🙏",
    "🙏🙏🙏🙏🙏🙏🙏",
    "Jai shree ram",
    "Jay ambe maa",
    "Jay ambe maa",
    "જય અંબાજી માં 🙏",
    "જય માતાજી",
    "Jay Mata di",
    "Jaimataki",
    "જય શ્રી રામ",
    "All people request real God Allah",
    "Jay maa ambe",
    "Jay Ambe maa 🚩🚩🚩",
    "Jay mata di",
    "Jay mata di",
    "Jay mata di",
    "Jay mata di",
    "जय હો મા અંબે માં",
    "Jay Ambe maa",
    "જય માં અંબે",
    "Most important chor 🤣🤣🤣",
    "જય અંબે મા",
    "Jay ambaji",
    "Ham gaye h bha gold h",
    "Mai gaya hu jay maa amba🙏",
    "જય અંબે",
    "સોમ નાથ મંદિર",
    "🤣",
    "Ol",
    "Jai Mata ji main darshan kar liya hun phir se Jana hai",
    "Maa jagdamba",
    "🤣🤣🤣🤣😂😂😂😂",
    "..",
    "8799180885",
    "Kya fayda hota hai vahan se Paisa milta Hai inko",
    "No",
    "Baba ji ka thullu",
    "Ambani desh ke bare kya sochte hai 🤷‍♂️🤣",
    "ye mandir unjha me hai...gujrat me",
    "Parivar sarkar daytha our harami haram ka Pisa kaywal gaddari bhut achay sanskar",
    "Mai khud hi jata hu ush mandir me navaratri me",
    "Bo gu khane ka bolega to Kha lenge Kya laode",
    "Mai is mandir me gaya hoon",
    "Jai Mata Di ❤️❤️❤️",
    "Jai mata di ❤️",
    "Jai mata di 🙏",
    "Jai Mata di 🙏",
    "Jai mata di 🙏🙏",
    "Jai mata di 🙏🙏",
    "Jay ambaji mata 🙏🏻🙏🏻🙏🏻🙏🏻🙏🏻🙏🏻",
    "Ok Jay man Ambaji"
]

# Positive emoji list
positive_emojis = ["❤️", "🙏","🙏", "🌺", "💓","❤️‍🩹", "♥️"," 😎", "👏", "🙇🏻‍♂️", "🌟", "🙌", "🍦", "🚩"]

# Function to get sentiment including emoji sentiment
def get_sentiment(comment):
    analysis = TextBlob(comment)
    emoji_positive_score = sum(comment.count(emoji) for emoji in positive_emojis) * 0.1
    # Returns combined polarity: -1 (negative) to +1 (positive)
    return analysis.sentiment.polarity + emoji_positive_score

# Applying the sentiment analysis
comments_df = pd.DataFrame(comments, columns=['Comment'])
comments_df['Sentiment'] = comments_df['Comment'].apply(get_sentiment)

# Categorizing sentiment
def categorize_sentiment(polarity):
    if polarity > 0:
        return 'Positive'
    elif polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

comments_df['Sentiment_Category'] = comments_df['Sentiment'].apply(categorize_sentiment)

# Display the results
print("Head", comments_df[:3])
print("Tail", comments_df[-4:])
print()

# Classify each comment
def classify_sentiment(comment):
    return categorize_sentiment(get_sentiment(comment))

sentiments = [classify_sentiment(comment) for comment in comments]

# Count the occurrences of each sentiment category
sentiment_counts = comments_df['Sentiment_Category'].value_counts()

# Extract counts for each sentiment category
positive_count = sentiment_counts.get('Positive', 0)
negative_count = sentiment_counts.get('Negative', 0)
neutral_count = sentiment_counts.get('Neutral', 0)

# Calculate total number of comments
total_comments = len(comments_df)

# Calculate percentages
positive_percentage = (positive_count / total_comments) * 100
negative_percentage = (negative_count / total_comments) * 100
neutral_percentage = (neutral_count / total_comments) * 100

# Print counts and percentages
print(f"positive_count: {positive_count}, negative_count: {negative_count}, neutral_count: {neutral_count}")
print(f"Positive Percentage: {positive_percentage:.2f}%, Negative Percentage: {negative_percentage:.2f}%, Neutral Percentage: {neutral_percentage:.2f}%")

# Sentiment score function
def get_sentiment_score(comment):
    return get_sentiment(comment)

# Create a list of tuples with comment and its sentiment score
comments_with_scores = [(comment, get_sentiment_score(comment)) for comment in comments]

# Sort the comments based on the absolute value of sentiment score in descending order
sorted_comments = sorted(comments_with_scores, key=lambda x: abs(x[1]), reverse=True)

# Select the top 10 comments
top_10_comments = sorted_comments[:10]

# Print the top 10 comments with their scores
print("\nTop 10 Comments Based on Sentiment Scores:")
for comment, score in top_10_comments:
    print(f"Comment: {comment}, Sentiment Score: {score:.2f}")
# Out:
# Head                               Comment  Sentiment Sentiment_Category
# 0                     Maa❤️❤️❤️❤️❤️❤️        0.6           Positive
# 1  I love you and your naychiral work        0.5           Positive
# 2                            ❤️❤️❤️❤️        0.4           Positive
# Tail                          Comment  Sentiment Sentiment_Category
# 84                Jai mata di 🙏🙏        0.4           Positive
# 85                Jai mata di 🙏🙏        0.4           Positive
# 86  Jay ambaji mata 🙏🏻🙏🏻🙏🏻🙏🏻🙏🏻🙏🏻        1.2           Positive
# 87             Ok Jay man Ambaji        0.5           Positive
#
# positive_count: 44, negative_count: 0, neutral_count: 44
# Positive Percentage: 50.00%, Negative Percentage: 0.00%, Neutral Percentage: 50.00%
#
# Top 10 Comments Based on Sentiment Scores:
# Comment: ❤️‍🩹❤️‍🩹❤️‍🩹❤️‍🩹❤️‍🩹❤️‍🩹❤️‍🩹❤️‍🩹, Sentiment Score: 1.60
# Comment: 🙏🙏🙏🙏जय अंबाजी माता 🙏🙏🙏, Sentiment Score: 1.40
# Comment: 🙏🙏🙏🙏🙏🙏🙏, Sentiment Score: 1.40
# ...

# %%
from textblob import TextBlob
import pandas as pd

# Reel 2: Anant Ambani’s journey into the business world! (Business Insight)
comments = [
    "Soo nice",
"Nice video",
"Nice",
"True love forever ha 😁🍫🦸🏻‍♂️💝🧚🙏 Jay ShreeKrishna 🙏🍫🥤🚩🌄",
"Congratulations sir 🥳🥰",
"Vijaya bhavahh 👍👌❤️😘💖💯🌹🙏🌹",
"Power of true love forever ha 😁🍫🦸🏻‍♂️💝🧚🙏 Jay ShreeKrishna 🙏🍫🥤🚩🌄",
"Good",
"Agnii Patth 👍👌😘❤️💖💯🌹😊😍",
"❤️❤️❤️🙌🔥❤️",
"👏",
"👍♥️",
"🥰",
"🌹🌹🌳❤️🕉️🌈👨‍👩‍👧🇮🇳",
"Monkey 🐒✍️ Babu ✈️ kee tarafa sa happy raho bacha 🌍",
"राम राम जी सा",
"Nil",
"अंबानी जी अपना भजन कम कर लो इतना वजन बढ़ा रहे हो यह आपको बीमारी है घर लेंगे आपका जीवन दवाइयां पर निर्भर हो जाएगा अभी मौका है जाग जाओ ओम नमो नारायण नमो नारायण",
"Hi",
"Moti Bhains",
"Haathi🐘🐘🐘🐘🐘",
"Hello",
"🤣🤣🤣🤣🤣🤣😄😄😄😁😀😅😂🤣😃😄😋😋😋😋😋😋",
"😂😂😂",
"Aapse baat krni hai muje🙏🙏",
"😂😂😂😂😂😂",
"🥵🥵🥵🥵🥵🥵",
"ओ",
"Hathi😂😂😂😂",
"Rs. 100000000. 👈👈👈👈",
"🦬🦬🦬🦬🦣🦣🦣🦣🦣🦣",
"मोटा माल",
"Farmer boy",
"Dhang Se Chala to Jata Nahin kya karna Aisi",
"Haathi ka bacha",
"गदड़े क़े गु का लेंडा लगता है",
"Motu",
"Motu aur Patlu ki Jodi"
]

# Positive emoji list
positive_emojis = ["❤️", "🙏","🙏", "🌺", "💓","❤️‍🩹", "♥️"," 😎", "👏", "🙇🏻‍♂️", "🌟", "🙌", "🍦", "🚩"]

# Function to get sentiment including emoji sentiment
def get_sentiment(comment):
    analysis = TextBlob(comment)
    emoji_positive_score = sum(comment.count(emoji) for emoji in positive_emojis) * 0.1
    # Returns combined polarity: -1 (negative) to +1 (positive)
    return analysis.sentiment.polarity + emoji_positive_score

# Applying the sentiment analysis
comments_df = pd.DataFrame(comments, columns=['Comment'])
comments_df['Sentiment'] = comments_df['Comment'].apply(get_sentiment)

# Categorizing sentiment
def categorize_sentiment(polarity):
    if polarity > 0:
        return 'Positive'
    elif polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

comments_df['Sentiment_Category'] = comments_df['Sentiment'].apply(categorize_sentiment)

# Display the results
print("Head", comments_df[:3])
print("Tail", comments_df[-4:])
print()
# Classify each comment
def classify_sentiment(comment):
  return categorize_sentiment(get_sentiment(comment))

sentiments = [classify_sentiment(comment) for comment in comments]

# Count the occurrences of each sentiment category
sentiment_counts = comments_df['Sentiment_Category'].value_counts()

# Extract counts for each sentiment category
positive_count = sentiment_counts.get('Positive', 0)
negative_count = sentiment_counts.get('Negative', 0)
neutral_count = sentiment_counts.get('Neutral', 0)

# Calculate total number of comments
total_comments = len(comments_df)

# Calculate percentages
positive_percentage = (positive_count / total_comments) * 100
negative_percentage = (negative_count / total_comments) * 100
neutral_percentage = (neutral_count / total_comments) * 100

# Print counts and percentages
print(f"positive_count: {positive_count}, negative_count: {negative_count}, neutral_count: {neutral_count}")
print(f"Positive Percentage: {positive_percentage:.2f}%, Negative Percentage: {negative_percentage:.2f}%, Neutral Percentage: {neutral_percentage:.2f}%")



# Sentiment score function
def get_sentiment_score(comment):
    return get_sentiment(comment)

# Create a list of tuples with comment and its sentiment score
comments_with_scores = [(comment, get_sentiment_score(comment)) for comment in comments]

# Sort the comments based on the absolute value of sentiment score in descending order
sorted_comments = sorted(comments_with_scores, key=lambda x: abs(x[1]), reverse=True)

# Select the top 10 comments
top_10_comments = sorted_comments[:10]

# Print the top 10 comments with their scores
print("\nTop 10 Comments Based on Sentiment Scores:")
for comment, score in top_10_comments:
    print(f"Comment: {comment}, Sentiment Score: {score:.2f}")
# Out:
# Head       Comment  Sentiment Sentiment_Category
# 0    Soo nice        0.6           Positive
# 1  Nice video        0.6           Positive
# 2        Nice        0.6           Positive
# Tail                         Comment  Sentiment Sentiment_Category
# 34              Haathi ka bacha        0.0            Neutral
# 35  गदड़े क़े गु का लेंडा लगता है        0.0            Neutral
# 36                         Motu        0.0            Neutral
# 37       Motu aur Patlu ki Jodi        0.0            Neutral
#
# positive_count: 14, negative_count: 0, neutral_count: 24
# Positive Percentage: 36.84%, Negative Percentage: 0.00%, Neutral Percentage: 63.16%
#
# Top 10 Comments Based on Sentiment Scores:
# Comment: True love forever ha 😁🍫🦸🏻‍♂️💝🧚🙏 Jay ShreeKrishna 🙏🍫🥤🚩🌄, Sentiment Score: 0.93
# Comment: Power of true love forever ha 😁🍫🦸🏻‍♂️💝🧚🙏 Jay ShreeKrishna 🙏🍫🥤🚩🌄, Sentiment Score: 0.93
# Comment: Good, Sentiment Score: 0.70
# Comment: Soo nice, Sentiment Score: 0.60
# ...

# %%
from textblob import TextBlob
import pandas as pd

# Reel 3: अंबानी की अनोखी पहल: वनतारा में पशु संरक्षण पर दृष्टिकोण ( Project Vantara)
comments = [
  "Good man 👍",
"Very nice",
"Great job 👏👍",
"Good job BHAi 🙂🙏",
"Nice",
"Good working ❤️❤️❤️",
"I like animals ❤️",
"Very good 💯",
"❤️❤️❤️❤️❤️",
"Thnx bro",
"Good think and good work......",
"❤️👍",
"जय श्रीराम",
"❤️❤️",
"Most healthy and wealthy person on earth",
"❤",
"👏",
"Hathi🐘 always love ❤️ elephant 🐘",
"Elephant 🐘 are happy 😊 & enjoying their new family member 😄",
"🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰",
"😍😍",
"😍",
"Jay Maa Tarini🙏❤️❤️❤️",
"।।।",
"VantaRa❤️",
"🔥🔥🔥🔥🔥🔥🔥",
"2 bhaiyo ka pyar",
"Sarahniya karya hai 👍🥰🥰",
"Ek hathi dusre se pyar karte hue",
"❤️*10007#",
"2hathi ek sth",
"Pppp",
"Do haathi ek sath",
"2 hathi in one frame😁",
"Do hathi ek saath",
"Do hathi ek sath",
"दो हाथी एक साथ दिख रहे है ।😂",
"Do do hathi",
"2 hathi ek sath ho gye😂😂",
"Khud uda rahe aur khud hi bacha rahe",
"2 hathi in one frame😁",
"Do hathi ek saath me 👌👌",
"Do haathi ek sath wow😁😂😂😂",
"2 hathi in one frame",
"Do haathi ek saath",
"Ek hathi dusre hathiyon ki madad karte hue",
"Elephant 🐘 is keeping an elephant 🐘",
"Ek hathi dusre hathi ke sath",
"Chhota hathi hai saath mai",
"Dono hathi ekk sath 🤣",
"2 elephants in one frame"
]

# Positive emoji list
positive_emojis = ["❤️", "🙏","🙏", "🌺", "💓","❤️‍🩹", "♥️"," 😎", "👏", "🙇🏻‍♂️", "🌟", "🙌", "🍦", "🚩"]

# Function to get sentiment including emoji sentiment
def get_sentiment(comment):
    analysis = TextBlob(comment)
    emoji_positive_score = sum(comment.count(emoji) for emoji in positive_emojis) * 0.1
    # Returns combined polarity: -1 (negative) to +1 (positive)
    return analysis.sentiment.polarity + emoji_positive_score

# Applying the sentiment analysis
comments_df = pd.DataFrame(comments, columns=['Comment'])
comments_df['Sentiment'] = comments_df['Comment'].apply(get_sentiment)

# Categorizing sentiment
def categorize_sentiment(polarity):
    if polarity > 0:
        return 'Positive'
    elif polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

comments_df['Sentiment_Category'] = comments_df['Sentiment'].apply(categorize_sentiment)

# Display the results
print("Head", comments_df[:3])
print("Tail", comments_df[-4:])
print()
# Classify each comment
def classify_sentiment(comment):
  return categorize_sentiment(get_sentiment(comment))

sentiments = [classify_sentiment(comment) for comment in comments]

# Count the occurrences of each sentiment category
sentiment_counts = comments_df['Sentiment_Category'].value_counts()

# Extract counts for each sentiment category
positive_count = sentiment_counts.get('Positive', 0)
negative_count = sentiment_counts.get('Negative', 0)
neutral_count = sentiment_counts.get('Neutral', 0)

# Calculate total number of comments
total_comments = len(comments_df)

# Calculate percentages
positive_percentage = (positive_count / total_comments) * 100
negative_percentage = (negative_count / total_comments) * 100
neutral_percentage = (neutral_count / total_comments) * 100

# Print counts and percentages
print(f"positive_count: {positive_count}, negative_count: {negative_count}, neutral_count: {neutral_count}")
print(f"Positive Percentage: {positive_percentage:.2f}%, Negative Percentage: {negative_percentage:.2f}%, Neutral Percentage: {neutral_percentage:.2f}%")

# Sentiment score function
def get_sentiment_score(comment):
    return get_sentiment(comment)

# Create a list of tuples with comment and its sentiment score
comments_with_scores = [(comment, get_sentiment_score(comment)) for comment in comments]

# Sort the comments based on the absolute value of sentiment score in descending order
sorted_comments = sorted(comments_with_scores, key=lambda x: abs(x[1]), reverse=True)

# Select the top 10 comments
top_10_comments = sorted_comments[:10]

# Print the top 10 comments with their scores
print("\nTop 10 Comments Based on Sentiment Scores:")
for comment, score in top_10_comments:
    print(f"Comment: {comment}, Sentiment Score: {score:.2f}")
# Out:
# Head         Comment  Sentiment Sentiment_Category
# 0    Good man 👍       0.70           Positive
# 1     Very nice       0.78           Positive
# 2  Great job 👏👍       0.90           Positive
# Tail                          Comment  Sentiment Sentiment_Category
# 47  Ek hathi dusre hathi ke sath        0.0            Neutral
# 48    Chhota hathi hai saath mai        0.0            Neutral
# 49         Dono hathi ekk sath 🤣        0.0            Neutral
# 50      2 elephants in one frame        0.0            Neutral
#
# positive_count: 19, negative_count: 0, neutral_count: 32
# Positive Percentage: 37.25%, Negative Percentage: 0.00%, Neutral Percentage: 62.75%
#
# Top 10 Comments Based on Sentiment Scores:
# Comment: Good working ❤️❤️❤️, Sentiment Score: 1.00
# Comment: Very good 💯, Sentiment Score: 0.91
# Comment: Great job 👏👍, Sentiment Score: 0.90
# Comment: Good job BHAi 🙂🙏, Sentiment Score: 0.90
# Comment: Very nice, Sentiment Score: 0.78
# ...

# %%
from textblob import TextBlob
import pandas as pd

#Reel 4: Hanuman Ji ke pas kitni shakthi hai? (Mythology Story)
comments = [
 "ai bajrangbali ❤️",
"Sath mai unn pur Ambani baba ki zadda kirpa hai 😂😂",
"Jay hanuman ji ❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️",
"Jay❤️❤️❤️❤️❤️❤️❤️❤️",
"Jay Hanuman ji ❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️",
"Jai Hanuman ji ❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️",
"जय बजरंग बली ❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️🙌🙌",
"Jay Hanuman ji❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️",
"Jai shree Ram ji Jai Hanuman ji ki Jai 😍😍❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️",
"Jay Hanuman ji ❤️❤️❤️❤️❤️❤️❤️",
"Jai hanuman ji ❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️",
"Jay hunuman ji ❤️❤️❤️❤️",
"Jai hanuman ji ❤❤❤❤❤❤❤❤❤❤❤❤❤❤",
"Jay hanuman ji❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️",
"Jay shree ram 🚩🙏🙏",
"जय श्री राम 🚩",
"Jay shree ram 🚩",
"Jai hanuman ji❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️"


]

# Positive emoji list
positive_emojis = ["❤️", "🙏","🙏", "🌺", "💓","❤️‍🩹", "♥️"," 😎", "👏", "🙇🏻‍♂️", "🌟", "🙌", "🍦", "🚩"]

# Function to get sentiment including emoji sentiment
def get_sentiment(comment):
    analysis = TextBlob(comment)
    emoji_positive_score = sum(comment.count(emoji) for emoji in positive_emojis) * 0.1
    # Returns combined polarity: -1 (negative) to +1 (positive)
    return analysis.sentiment.polarity + emoji_positive_score

# Applying the sentiment analysis
comments_df = pd.DataFrame(comments, columns=['Comment'])
comments_df['Sentiment'] = comments_df['Comment'].apply(get_sentiment)

# Categorizing sentiment
def categorize_sentiment(polarity):
    if polarity > 0:
        return 'Positive'
    elif polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

comments_df['Sentiment_Category'] = comments_df['Sentiment'].apply(categorize_sentiment)

# Display the results
print("Head", comments_df[:3])
print("Tail", comments_df[-4:])
print()
# Classify each comment
def classify_sentiment(comment):
  return categorize_sentiment(get_sentiment(comment))

sentiments = [classify_sentiment(comment) for comment in comments]
# Count the occurrences of each sentiment category
sentiment_counts = comments_df['Sentiment_Category'].value_counts()

# Extract counts for each sentiment category
positive_count = sentiment_counts.get('Positive', 0)
negative_count = sentiment_counts.get('Negative', 0)
neutral_count = sentiment_counts.get('Neutral', 0)

# Calculate total number of comments
total_comments = len(comments_df)

# Calculate percentages
positive_percentage = (positive_count / total_comments) * 100
negative_percentage = (negative_count / total_comments) * 100
neutral_percentage = (neutral_count / total_comments) * 100

# Print counts and percentages
print(f"positive_count: {positive_count}, negative_count: {negative_count}, neutral_count: {neutral_count}")
print(f"Positive Percentage: {positive_percentage:.2f}%, Negative Percentage: {negative_percentage:.2f}%, Neutral Percentage: {neutral_percentage:.2f}%")

# Sentiment score function
def get_sentiment_score(comment):
    return get_sentiment(comment)

# Create a list of tuples with comment and its sentiment score
comments_with_scores = [(comment, get_sentiment_score(comment)) for comment in comments]

# Sort the comments based on the absolute value of sentiment score in descending order
sorted_comments = sorted(comments_with_scores, key=lambda x: abs(x[1]), reverse=True)

# Select the top 10 comments
top_10_comments = sorted_comments[:10]

# Print the top 10 comments with their scores
print("\nTop 10 Comments Based on Sentiment Scores:")
for comment, score in top_10_comments:
    print(f"Comment: {comment}, Sentiment Score: {score:.2f}")
# Out:
# Head                                              Comment  Sentiment  \
# 0                                  ai bajrangbali ❤️        0.1
# 1  Sath mai unn pur Ambani baba ki zadda kirpa ha...        0.0
# 2  Jay hanuman ji ❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤...        2.1
#
#   Sentiment_Category
# 0           Positive
# 1            Neutral
# 2           Positive
# Tail                                               Comment  Sentiment  \
# 14                                  Jay shree ram 🚩🙏🙏        0.5
# 15                                      जय श्री राम 🚩        0.1
# 16                                    Jay shree ram 🚩        0.1
# 17  Jai hanuman ji❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️...        7.9
#
#    Sentiment_Category
# 14           Positive
# 15           Positive
# 16           Positive
# 17           Positive
#
# positive_count: 16, negative_count: 0, neutral_count: 2
# Positive Percentage: 88.89%, Negative Percentage: 0.00%, Neutral Percentage: 11.11%
#
# ...

# %%
from textblob import TextBlob
import pandas as pd

#Reel 5: Mera bhi mera sam ne hai - Anant Ambani (Mythology Story)
comments = [
 "Good boy",
"Goodbhai",
"Superb😊👌",
"So cute so good",
"Very nice",
"Very nice",
"Good 👍",
"Good 👍",
"Nice",
"Nice",
"Nice",
"Super",
"God bless u",
"❤️ good very good very nice excellent out of performance wah wah kya vichar hai",
"Bhai behen bhaiyon ka pyar ❤️",
"Wow❤️❤️",
"👏👏👏",
"V nice",
"Super hero 👍🙏",
"❤️",
"❤❤❤❤",
"बहुत बढ़िया बेटा जी जय श्री राम",
"जय श्री राम 🚩🚩",
"🥰🤩🥰👍👍💪💪",
"जय श्री राम",
"Jai ho",
"Jai shree Ram 🙏🚩",
"Jay Shri Ram 🙏🙏🙏🚩🚩🚩🚩🚩🚩",
"👍",
"Jai Shree ram!",
"Sanskar ❤️🙏🙏👍",
"Jay Shri Ram 🙏",
"Jai Shri ram",
"Sanskari Bete ki yahi pahchan Hoti hai sada khush raho na🥰😍👑",
"Jai shree ram",
"Jai shree ram",
"Jai shree ram",
"Jai shree ram",
"Jai shree Ram",
"Jai shree Ram",
"Jay Jay Shri Ram",
"😊🥰",
"Jai Siya Ram ji",
"😜",
"👌👌👌👌👌",
"Yah Sanskar Sanatan Dharm ke Jay Shri Ram",
"Jai shri ram",
"सिताराम",
"Anand Ambani future life partner good support but take care double cross",
"Shaabas beta",
"Om Sai Ram",
"Bahut badhiya bhai",
"Jay Hanuman 🤓🤓",
"Sanskar ❤️🙏🙏👍",
"In the year 1813, like Sant Dadu Ji and Sant Garibdas Ji, 7 year old Sant Gheesa Das Ji of village Khekhra (District Meerut, Uttar Pradesh) met God Kabir in the form of a living Mahatma and showed him Satlok.",
"Again and again picture",
"Ab pata chala pappu aur Ram virodhi yo ko adani Ambani se kyu nafrat hai.... Jai Shree Ram 🧡",
"भाजपा की जीत का मूल मंत्र 👇",
"भाजपा का 90% कार्यकर्ता ऐसा हैं।",
"जो चुनाव के वक़्त आता हैं माहौल बदलता हैं सरकार बनवाता हैं ओर गायब हो जाता हैं।",
"उसको उसके मोहल्ले का भाजपा नेता तक नहीं जानता लेकिन वो अपनी जिम्मेदारी समझता हैं।",
"ख़ुद को मोदी जी से कम नहीं समझता हैं 💪🚩 #india",
"Jay shir RAM",
"😂😂",
"😂😂",
"😂😂😂😂",
"😂😂😂😂",
"😂😂😂😂😂😂",
"🤣🤣🤣🤣",
"🤣🤣🤣🤣",
"🤣🤣🤣🤣🤣",
"🤣🤣🤣🤣🤣🤣",
"🤣🤣🤣🤣🤣🤣",
"🤣🤣🤣🤣🤣🤣",
"🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣",
"🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣",
"🤣🤣🤣🤣🤣🤣",
"Hanuman ❌Gian🙂✅",
"😂😂😂😂😂😂",
"Hanuman nahi hai Ganda hai",
"Giaan ho tum 😅",
"B😃😃😃😃😃😃😃",
"🤣🤣🤣",
"🤣🤣🤣🤣🤣🤣",
"🤣🤣😥😝",
"मुझे 10 लाख रुपया दे दीजिए एमपी झाबुआ जिला मध्य प्रदेश थाना गांव और मेरी जरूरत है घर बनाना है",
"All script bro's can anyone post against them while after personal interview 😂",
"Ab pata chala pappu aur Ram virodhi yo ko adani Ambani se kyu nafrat hai.... Jai Shree Ram"

]

# Positive emoji list
positive_emojis = ["❤️", "🙏","🙏", "🌺", "💓","❤️‍🩹", "♥️"," 😎", "👏", "🙇🏻‍♂️", "🌟", "🙌", "🍦", "🚩"]

# Function to get sentiment including emoji sentiment
def get_sentiment(comment):
    analysis = TextBlob(comment)
    emoji_positive_score = sum(comment.count(emoji) for emoji in positive_emojis) * 0.1
    # Returns combined polarity: -1 (negative) to +1 (positive)
    return analysis.sentiment.polarity + emoji_positive_score

# Applying the sentiment analysis
comments_df = pd.DataFrame(comments, columns=['Comment'])
comments_df['Sentiment'] = comments_df['Comment'].apply(get_sentiment)

# Categorizing sentiment
def categorize_sentiment(polarity):
    if polarity > 0:
        return 'Positive'
    elif polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

comments_df['Sentiment_Category'] = comments_df['Sentiment'].apply(categorize_sentiment)

# Display the results
print("Head", comments_df[:3])
print("Tail", comments_df[-4:])
print()
# Classify each comment
def classify_sentiment(comment):
  return categorize_sentiment(get_sentiment(comment))

sentiments = [classify_sentiment(comment) for comment in comments]

# Count the occurrences of each sentiment category
sentiment_counts = comments_df['Sentiment_Category'].value_counts()

# Extract counts for each sentiment category
positive_count = sentiment_counts.get('Positive', 0)
negative_count = sentiment_counts.get('Negative', 0)
neutral_count = sentiment_counts.get('Neutral', 0)

# Calculate total number of comments
total_comments = len(comments_df)

# Calculate percentages
positive_percentage = (positive_count / total_comments) * 100
negative_percentage = (negative_count / total_comments) * 100
neutral_percentage = (neutral_count / total_comments) * 100

# Print counts and percentages
print(f"positive_count: {positive_count}, negative_count: {negative_count}, neutral_count: {neutral_count}")
print(f"Positive Percentage: {positive_percentage:.2f}%, Negative Percentage: {negative_percentage:.2f}%, Neutral Percentage: {neutral_percentage:.2f}%")

# Sentiment score function
def get_sentiment_score(comment):
    return get_sentiment(comment)

# Create a list of tuples with comment and its sentiment score
comments_with_scores = [(comment, get_sentiment_score(comment)) for comment in comments]

# Sort the comments based on the absolute value of sentiment score in descending order
sorted_comments = sorted(comments_with_scores, key=lambda x: abs(x[1]), reverse=True)

# Select the top 10 comments
top_10_comments = sorted_comments[:10]

# Print the top 10 comments with their scores
print("\nTop 10 Comments Based on Sentiment Scores:")
for comment, score in top_10_comments:
    print(f"Comment: {comment}, Sentiment Score: {score:.2f}")
# Out:
# Head     Comment  Sentiment Sentiment_Category
# 0  Good boy        0.7           Positive
# 1  Goodbhai        0.0            Neutral
# 2  Superb😊👌        0.0            Neutral
# Tail                                               Comment  Sentiment  \
# 84                                               🤣🤣😥😝        0.0
# 85  मुझे 10 लाख रुपया दे दीजिए एमपी झाबुआ जिला मध्...        0.0
# 86  All script bro's can anyone post against them ...        0.0
# 87  Ab pata chala pappu aur Ram virodhi yo ko adan...        0.0
#
#    Sentiment_Category
# 84            Neutral
# 85            Neutral
# 86            Neutral
# 87            Neutral
#
# positive_count: 26, negative_count: 0, neutral_count: 62
# Positive Percentage: 29.55%, Negative Percentage: 0.00%, Neutral Percentage: 70.45%
#
# Top 10 Comments Based on Sentiment Scores:
# Comment: Jay Shri Ram 🙏🙏🙏🚩🚩🚩🚩🚩🚩, Sentiment Score: 1.20
# ...

# %%
from textblob import TextBlob
import pandas as pd

#Reel 6:Apne jaise ko nahi Bhula chahiye - Anant Ambani (Mythology Story)
comments = [
 "क्या बात है! धर्म के प्रति ऐसी भावना देखकर खुशी होती है।",
"A beautiful journey through Hindu beliefs.",
"Amazing insights into divine love and family.",
"ति आपकी भावनाएँ प्रेरणादायक हैं।",
"बहुत ही प्रेरणादायक! शुक्रिया इसे शेयर करने के लिए।",
"शब्दों में जीवन के गहरे अर्थ मिलते हैं।",
"Incredible understanding of Hindu values.",
"A perfect explanation of complex concepts.",
"यह वीडियो परिवार के महत्व को बढ़ाता है।",
"जय श्री राम 🙏",
"❤️",
"Jai Shri Ram 🙏 🚩 🇮🇳",
"💝💝✨",
"Jai ho",
"💯🚩🙏🙏",
"Jai Sree Ram ❤️🚩",
"🚩 Jay 🛐 shree 🙏 ram 🚩 jay 🛐 bajarang 🙏 bali",
"Jay shree ram",
"राधे राधे 🚩",
"❤️ jay shri Ram",
"😂😂😂😂😂😂😂😂😂😂😂it's TRUE 😂😂😂😂😂😂😂😂. jay 🙏shree ram 🙏",
"😂😂😂😂",
"Humpty Dumpty",
"எதைக் கொண்டு வந்தாய் எதைக் கொண்டு செல்ல பாவப்பட்ட இப்ப ஜென்மத்துக்கு உதவி பண்ணுங்க",
"Poda punda",
"Vo video kaha gayi jisme ye Apne se bade aadami se pair",
"Tum manse bhi aamir ho",
"Ye bhi affrican panda jaisa 😂😂",
"Or inke baap se bhi jyada age ke employee eske peron ko",
"Or apne se bado ko apne pair chhune Dene chahiye 😂😁 ye",
"BSNL ka tower chala rahi hai uska kya BSNL ko government ne",
"🖕",
"Business kaise chalega",
"इतना सही बोला आपने",
"एको करोड़ दान करदो सर मुझे भी"

]

# Positive emoji list
positive_emojis = ["❤️", "🙏","🙏", "🌺", "💓","❤️‍🩹", "♥️"," 😎", "👏", "🙇🏻‍♂️", "🌟", "🙌", "🍦", "🚩"]

# Function to get sentiment including emoji sentiment
def get_sentiment(comment):
    analysis = TextBlob(comment)
    emoji_positive_score = sum(comment.count(emoji) for emoji in positive_emojis) * 0.1
    # Returns combined polarity: -1 (negative) to +1 (positive)
    return analysis.sentiment.polarity + emoji_positive_score

# Applying the sentiment analysis
comments_df = pd.DataFrame(comments, columns=['Comment'])
comments_df['Sentiment'] = comments_df['Comment'].apply(get_sentiment)

# Categorizing sentiment
def categorize_sentiment(polarity):
    if polarity > 0:
        return 'Positive'
    elif polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

comments_df['Sentiment_Category'] = comments_df['Sentiment'].apply(categorize_sentiment)

# Display the results
print("Head", comments_df[:3])
print("Tail", comments_df[-4:])
print()
# Classify each comment
def classify_sentiment(comment):
  return categorize_sentiment(get_sentiment(comment))

sentiments = [classify_sentiment(comment) for comment in comments]
# Count the occurrences of each sentiment category
sentiment_counts = comments_df['Sentiment_Category'].value_counts()

# Extract counts for each sentiment category
positive_count = sentiment_counts.get('Positive', 0)
negative_count = sentiment_counts.get('Negative', 0)
neutral_count = sentiment_counts.get('Neutral', 0)

# Calculate total number of comments
total_comments = len(comments_df)

# Calculate percentages
positive_percentage = (positive_count / total_comments) * 100
negative_percentage = (negative_count / total_comments) * 100
neutral_percentage = (neutral_count / total_comments) * 100

# Print counts and percentages
print(f"positive_count: {positive_count}, negative_count: {negative_count}, neutral_count: {neutral_count}")
print(f"Positive Percentage: {positive_percentage:.2f}%, Negative Percentage: {negative_percentage:.2f}%, Neutral Percentage: {neutral_percentage:.2f}%")

# Sentiment score function
def get_sentiment_score(comment):
    return get_sentiment(comment)

# Create a list of tuples with comment and its sentiment score
comments_with_scores = [(comment, get_sentiment_score(comment)) for comment in comments]

# Sort the comments based on the absolute value of sentiment score in descending order
sorted_comments = sorted(comments_with_scores, key=lambda x: abs(x[1]), reverse=True)

# Select the top 10 comments
top_10_comments = sorted_comments[:10]

# Print the top 10 comments with their scores
print("\nTop 10 Comments Based on Sentiment Scores:")
for comment, score in top_10_comments:
    print(f"Comment: {comment}, Sentiment Score: {score:.2f}")
# Out:
# Head                                              Comment  Sentiment  \
# 0  क्या बात है! धर्म के प्रति ऐसी भावना देखकर खुश...       0.00
# 1         A beautiful journey through Hindu beliefs.       0.85
# 2      Amazing insights into divine love and family.       0.55
#
#   Sentiment_Category
# 0            Neutral
# 1           Positive
# 2           Positive
# Tail                           Comment  Sentiment Sentiment_Category
# 31                              🖕        0.0            Neutral
# 32         Business kaise chalega        0.0            Neutral
# 33             इतना सही बोला आपने        0.0            Neutral
# 34  एको करोड़ दान करदो सर मुझे भी        0.0            Neutral
#
# positive_count: 13, negative_count: 0, neutral_count: 22
# Positive Percentage: 37.14%, Negative Percentage: 0.00%, Neutral Percentage: 62.86%
#
# Top 10 Comments Based on Sentiment Scores:
# Comment: Incredible understanding of Hindu values., Sentiment Score: 0.90
# ...
